# %% [markdown]
# #Series
#
# A Pandas Series is a one-dimensional, labeled array capable of holding data of any type

# %%
# !pip install numpy pandas
import numpy as np
import pandas as pd
# Out:
# Requirement already satisfied: numpy in c:\users\pamith\anaconda3\envs\torch_env\lib\site-packages (2.2.5)
# Requirement already satisfied: pandas in c:\users\pamith\anaconda3\envs\torch_env\lib\site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pamith\anaconda3\envs\torch_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pamith\anaconda3\envs\torch_env\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pamith\anaconda3\envs\torch_env\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\pamith\anaconda3\envs\torch_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
strings = ["Alpha","Beta","Gama"]
integers = [10,20,30]
array = np.array([40,50,60])
dictionary = {1:"JAVA" , 2:"PYTHON" , 3:"C++"}

# %% [markdown]
# #Priting String

# %%
print(pd.Series(strings))
# Out:
# 0    Alpha
# 1     Beta
# 2     Gama
# dtype: object

# %% [markdown]
# #print integers

# %%
print(pd.Series(integers))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# #Print array

# %%
print(pd.Series(array))
# Out:
# 0    40
# 1    50
# 2    60
# dtype: int64

# %% [markdown]
# #Print dictionary

# %%
print(pd.Series(dictionary))
# Out:
# 1      JAVA
# 2    PYTHON
# 3       C++
# dtype: object

# %% [markdown]
# #Replacing Index

# %%
print(pd.Series(integers,index = ["a","b","c"]) )#Single inverted commas can be  used too example'a','b'
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# #Using diff series for index

# %%
print(pd.Series(integers,index = strings))
# Out:
# Alpha    10
# Beta     20
# Gama     30
# dtype: int64

# %%
data = {
    "Name": ["Aarav", "Priya", "Rahul"],
    "Salary": [45000, 52000, 48000],
    "City": ["Pune", "Mumbai", "Delhi"]
}

df = pd.DataFrame(data)

df
# Out:
#     Name  Salary    City
# 0  Aarav   45000    Pune
# 1  Priya   52000  Mumbai
# 2  Rahul   48000   Delhi

# %%
data = [
    ["Aarav", 45000, "Pune"],
    ["Priya", 52000, "Mumbai"],
    ["Rahul", 48000, "Delhi"]
]

df = pd.DataFrame(data, columns=["Name", "Salary", "City"])

df
# Out:
#     Name  Salary    City
# 0  Aarav   45000    Pune
# 1  Priya   52000  Mumbai
# 2  Rahul   48000   Delhi

# %%
df["Name"]
# Out:
# 0    Aarav
# 1    Priya
# 2    Rahul
# Name: Name, dtype: object

# %%
df[["Name", "Salary"]]
# Out:
#     Name  Salary
# 0  Aarav   45000
# 1  Priya   52000
# 2  Rahul   48000

# %%
df.loc[0]
# Out:
# Name      Aarav
# Salary    45000
# City       Pune
# Name: 0, dtype: object

# %%
df.loc[0:1]
# Out:
#     Name  Salary    City
# 0  Aarav   45000    Pune
# 1  Priya   52000  Mumbai

# %%
df.loc[0:1, ["Name", "City"]]
# Out:
#     Name    City
# 0  Aarav    Pune
# 1  Priya  Mumbai

# %%
df.iloc[0]
# Out:
# Name      Aarav
# Salary    45000
# City       Pune
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#     Name  Salary    City
# 0  Aarav   45000    Pune
# 1  Priya   52000  Mumbai

# %%
df["Age"] = [24,24,21]
df
# Out:
#     Name  Salary    City  Age
# 0  Aarav   45000    Pune   24
# 1  Priya   52000  Mumbai   24
# 2  Rahul   48000   Delhi   21

# %% [markdown]
# #Drop Function

# %%
df.drop("Age")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.drop("Age")
#
# File c:\Users\Pamith\anaconda3\envs\torch_env\lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\Pamith\anaconda3\envs\torch_env\lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\Pamith\anaconda3\envs\torch_env\lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\Pamith\anaconda3\envs\torch_env\lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %%
df.drop("Age",axis=1)
# Out:
#     Name  Salary    City
# 0  Aarav   45000    Pune
# 1  Priya   52000  Mumbai
# 2  Rahul   48000   Delhi

# %%
df
# Out:
#     Name  Salary    City  Age
# 0  Aarav   45000    Pune   24
# 1  Priya   52000  Mumbai   24
# 2  Rahul   48000   Delhi   21

# %%
df.drop("Age",axis=1,inplace=True)

# %%
df
# Out:
#     Name  Salary    City
# 0  Aarav   45000    Pune
# 1  Priya   52000  Mumbai
# 2  Rahul   48000   Delhi
